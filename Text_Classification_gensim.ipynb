# %%
import gensim.downloader as api
wv = api.load('word2vec-google-news-300')

# %%
import pandas as pd
data = pd.read_json('News_Category_Dataset_v3.json',lines =True)
data
# Out:
#                                                      link  ...       date
# 0       https://www.huffpost.com/entry/covid-boosters-...  ... 2022-09-23
# 1       https://www.huffpost.com/entry/american-airlin...  ... 2022-09-23
# 2       https://www.huffpost.com/entry/funniest-tweets...  ... 2022-09-23
# 3       https://www.huffpost.com/entry/funniest-parent...  ... 2022-09-23
# 4       https://www.huffpost.com/entry/amy-cooper-lose...  ... 2022-09-22
# ...                                                   ...  ...        ...
# 209522  https://www.huffingtonpost.com/entry/rim-ceo-t...  ... 2012-01-28
# 209523  https://www.huffingtonpost.com/entry/maria-sha...  ... 2012-01-28
# 209524  https://www.huffingtonpost.com/entry/super-bow...  ... 2012-01-28
# 209525  https://www.huffingtonpost.com/entry/aldon-smi...  ... 2012-01-28
# 209526  https://www.huffingtonpost.com/entry/dwight-ho...  ... 2012-01-28
#
# [209527 rows x 6 columns]

# %%
data.category.value_counts()
# Out:
# POLITICS          35602
# WELLNESS          17945
# ENTERTAINMENT     17362
# TRAVEL             9900
# STYLE & BEAUTY     9814
# PARENTING          8791
# HEALTHY LIVING     6694
# QUEER VOICES       6347
# FOOD & DRINK       6340
# BUSINESS           5992
# COMEDY             5400
# SPORTS             5077
# BLACK VOICES       4583
# HOME & LIVING      4320
# PARENTS            3955
# THE WORLDPOST      3664
# WEDDINGS           3653
# WOMEN              3572
# CRIME              3562
# IMPACT             3484
# DIVORCE            3426
# WORLD NEWS         3299
# MEDIA              2944
# WEIRD NEWS         2777
# GREEN              2622
# WORLDPOST          2579
# RELIGION           2577
# STYLE              2254
# SCIENCE            2206
# TECH               2104
# TASTE              2096
# MONEY              1756
# ARTS               1509
# ENVIRONMENT        1444
# FIFTY              1401
# GOOD NEWS          1398
# U.S. NEWS          1377
# ARTS & CULTURE     1339
# ...

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
data['output'] = encoder.fit_transform(data.category)
data
# Out:
#                                                      link  ... output
# 0       https://www.huffpost.com/entry/covid-boosters-...  ...     35
# 1       https://www.huffpost.com/entry/american-airlin...  ...     35
# 2       https://www.huffpost.com/entry/funniest-tweets...  ...      5
# 3       https://www.huffpost.com/entry/funniest-parent...  ...     22
# 4       https://www.huffpost.com/entry/amy-cooper-lose...  ...     35
# ...                                                   ...  ...    ...
# 209522  https://www.huffingtonpost.com/entry/rim-ceo-t...  ...     32
# 209523  https://www.huffingtonpost.com/entry/maria-sha...  ...     28
# 209524  https://www.huffingtonpost.com/entry/super-bow...  ...     28
# 209525  https://www.huffingtonpost.com/entry/aldon-smi...  ...     28
# 209526  https://www.huffingtonpost.com/entry/dwight-ho...  ...     28
#
# [209527 rows x 7 columns]

# %%
import spacy
nlp = spacy.load("en_core_web_lg")
def preprocess(text):
    doc = nlp(text)
    filter_word =[]
    for token in doc:
        if token.is_punct or token.is_stop:
            continue
        filter_word.append(token.lemma_)
    return wv.get_mean_vector(filter_word)

# %%
data['vector'] = data['headline'].astype(str).apply(lambda x : preprocess(x))

# %%
import numpy as np
from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(data.vector.values,data.output,test_size=0.2,random_state =2000)

# %%
xtr = np.stack(xtrain)
xte = np.stack(xtest)
from sklearn.preprocessing import MinMaxScaler
from sklearn.naive_bayes import MultinomialNB
scaler = MinMaxScaler()
model = MultinomialNB()
s_xtrain = scaler.fit_transform(xtr)
s_xtest = scaler.fit_transform(xte)
model.fit_transform(s_xtrain,ytrain)
prediction = model.predict(s_xtest)
from sklearn.metrics import classification_report
print(classification_report(yte,prediction))

# %%
from sklearn.metrics import confusion_matrix
cm  = confusion_matrix(yte,prediction)
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(10,7))
sns.heatmap(cm,annot=True,fmt='d')
plt.xlabel('Prediction')
plt.ylabel('Actual')
